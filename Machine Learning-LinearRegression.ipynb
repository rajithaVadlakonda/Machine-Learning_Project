# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.linear_model import LinearRegression

# %%
pip install -U scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\windows10\anaconda3\lib\site-packages (1.5.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.19.5 in c:\users\windows10\anaconda3\lib\site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\windows10\anaconda3\lib\site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\windows10\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\windows10\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)

# %%
# Linear Regression with single variable
df=pd.read_excel("C:/Users/Windows10/Documents/Book1.xlsx")
df
# Out:
#    area   price
# 0  2600  500000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('area(sqr ft)')
plt.ylabel('price(US)')
plt.scatter(df.area,df.price,color="red",marker="+")
plt.plot(df.area,reg.predict(df[['area']].values),color='blue')

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['area']].values,df.price)
# Out:
# LinearRegression()

# %%
# to predict certain area price
reg.predict([[5000]])
# Out:
# array([899623.28767123])

# %%
reg.coef_
# Out:
# array([164.89726027])

# %%
reg.intercept_
# Out:
# 75136.98630136985

# %%
#y=m*x+c
164.89726027*3500+75136.98630136985
# Out:
# 652277.3972463699

# %%
# Linear Regression with multiple variable
df2=pd.read_excel("C:/Users/Windows10/Documents/Book2.xlsx")
df2
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000

# %%
import math
median_bedrooms=math.floor(df2.bedrooms.median())
median_bedrooms
# Out:
# 3

# %%
df2.bedrooms=df2.bedrooms.fillna(median_bedrooms)
df2
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       3.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000

# %%
reg=linear_model.LinearRegression()
reg.fit(df2[["area","bedrooms","age"]].values,df2.price)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([   137.25, -26025.  ,  -6825.  ])

# %%
reg.intercept_
# Out:
# 383724.9999999998

# %%
reg.predict([[3000,3,40]])
# Out:
# array([444400.])

# %%
3000*137.25+(-26025*3)+(-6825)*40+383724.9999999998
# Out:
# 444399.9999999998

# %%
# read the multiple independent variable data
df3=pd.read_excel("C:/Users/Windows10/Documents/Book3.xlsx")
df3
# Out:
#   experience  test_score  interview_score  salary($)
# 0        NaN         8.0                9      50000
# 1        NaN         8.0                6      45000
# 2       five         6.0                7      60000
# 3        two        10.0               10      65000
# 4      seven         9.0                6      70000
# 5      three         7.0               10      62000
# 6        ten         NaN                7      72000
# 7     eleven         7.0                8      80000

# %%
pip install word2number
# Out:
# Requirement already satisfied: word2number in c:\users\windows10\anaconda3\lib\site-packages (1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
df3.experience = df3.experience.fillna("zero")
df3
# Out:
#   experience  test_score  interview_score  salary($)
# 0       zero         8.0                9      50000
# 1       zero         8.0                6      45000
# 2       five         6.0                7      60000
# 3        two        10.0               10      65000
# 4      seven         9.0                6      70000
# 5      three         7.0               10      62000
# 6        ten         NaN                7      72000
# 7     eleven         7.0                8      80000

# %%
from word2number import w2n
df3.experience=df3.experience.apply(w2n.word_to_num)

# %%
import math
median_test_score = math.floor(df3['test_score'].mean())
median_test_score
# Out:
# 7

# %%
df3['test_score'] = df3['test_score'].fillna(median_test_score)
df3

# %%
reg=linear_model.LinearRegression()
reg.fit(df3[['experience','test_score','interview_score']].values,df3['salary($)'])

# %%
reg.predict([[2,9,6]])

# %%
reg.predict([[12,10,10]])
